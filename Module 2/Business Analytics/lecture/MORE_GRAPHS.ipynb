# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'])

# %%
df.head()
# Out:
#        data
# 0  1.390457
# 1  1.519250
# 2  1.964768
# 3  1.639190
# 4 -0.612510

# %%
df.plot();

# %%
df = pd.DataFrame(np.random.randn(1000) , columns=['data'],index  = pd.date_range('2022/03/26',periods = 1000))

# %%
df
# Out:
#                 data
# 2022-03-26  2.541575
# 2022-03-27  1.088864
# 2022-03-28 -0.351718
# 2022-03-29 -1.028796
# 2022-03-30  0.480550
# ...              ...
# 2024-12-15  0.905587
# 2024-12-16 -0.432286
# 2024-12-17  0.957720
# 2024-12-18  1.305521
# 2024-12-19 -0.104257
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10));

# %%
df = pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df=df.drop("Id",axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(20,10));
plt.savefig("image")

# %%
df.plot(kind='bar',figsize=(20,10));

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10));

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10));

# %%
df.plot(kind='hist',figsize=(20,10));

# %%
df['SepalLengthCm'].plot(kind='hist',figsize=(20,10));

# %%
df['SepalLengthCm'].plot(kind='hist',figsize=(20,10),orientation='horizontal');

# %%
df.hist(figsize=(20,10),grid=True,color='g',alpha=0.6);
# alpha is control the intensity of color

# %%
df.plot(kind='box',figsize=(20,10),color = {'boxes' : 'g' , 'whiskers' :'r'});

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.plot(kind='area',figsize=(20,10));

# %%
df.plot(kind='area',figsize=(20,10),stacked=False);

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm');

# %%
df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm',gridsize=10);

# %%
df1 = df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
# !pip install plotly
# Out:
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# ...

# %%
# !pip install cufflinks
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\dell\anaconda\anaconda3\lib\site-packages)
# ...

# %%
import cufflinks  as cf
cf.go_offline()
#cufflinks is offline version of plotly
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# for google colab pls uncomment below two lines of codes then only plotly will work
#import plotly.io as pio
#pio.renderers.default = "colab"

# %%
df.iplot()
# Out:
# <div>                            <div id="8666303c-2354-4864-9dae-a90b704f8069" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm',y='PetalLengthCm',mode='markers')
# Out:
# <div>                            <div id="f8ceb39e-17b3-48e9-a645-9429cb0690cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers',size=5)
#size of dots
# Out:
# <div>                            <div id="fab67ba1-9b2b-4ac6-9ba7-f08dffe6ffc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='SepalLengthCm',y='PetalLengthCm',size='SepalWidthCm')
# Out:
# <div>                            <div id="2256cc2c-1406-478f-a06e-3f525ed39b61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="807a7e52-6917-4930-9028-b6838ba28d2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter3d',x='SepalLengthCm',z='PetalLengthCm',y='SepalWidthCm')
# Out:
# <div>                            <div id="2422a5af-0e77-4108-a415-818d06a0d600" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind ='bubble3d' , x ='SepalLengthCm' , y ='SepalWidthCm' , z= 'PetalLengthCm' ,size =  'PetalWidthCm')
# Out:
# <div>                            <div id="543524ec-3ba5-42aa-b281-0e6b312da1ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day' , y = 'total_bill', data = df1);

# %%
sns.catplot(x = 'day' , y = 'tip', data = df1 , kind = 'swarm');
# Out:
# C:\Users\Dell\anaconda\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning:
#
# 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
sns.catplot(x='day',y='total_bill',data=df1,kind='box');

# %%
sns.catplot(x = 'day' , y = 'tip',kind = 'box' , data = df1,hue = 'sex')
